# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
sns.set_palette('colorblind')
sns.set_style('white')
# Out:
# /Users/navdeepgill/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
trump_tweets = pd.read_csv('realdonaldtrump_tweets.csv')
clinton_tweets = pd.read_csv('hillaryclinton_tweets.csv')

trump_tweets["author"] = "Trump"
clinton_tweets["author"] = "Clinton"

tweets = pd.concat([trump_tweets, clinton_tweets])
tweets = tweets[[ u'id', u'text', u'created_at', u'favorite_count', u'retweet_count', u'author']]
tweets["id"] = tweets["id"].astype("str")
tweets = tweets.reset_index()
tweets = tweets.drop("index",1)
tweets
# Out:
#                       id                                               text  \
# 0     783436108176629760  Thank you ARIZONA! This is a MOVEMENT like nob...
# 1     783393314309484544  My childcare plan makes a difference for worki...
# 2     783391423663964160  I will be watching the great Governor @Mike_Pe...
# 3     783390310969651200  Join me in Reno, Nevada tomorrow at 3:30pm! #A...
# 4     783149570721144832  Join me in Reno, Nevada on Wednesday at 3:30pm...
# 5     783129603363659776  Thank you Colorado! #MAGA\nhttps://t.co/3KWOl2...
# 6     783065029172088832  We must bring the truth directly to hard-worki...
# 7     783059449128759296  Thank you Pueblo, Colorado! \n#TrumpRally #Ame...
# 8     782946021957599232  Join me in Henderson, Nevada on Wednesday at 1...
# 9     782728287718150144  Just announced that Iraq (U.S.) is preparing f...
# 10    782701472685420544  Melania and I extend our warmest greetings to ...
# 11    782698760514207744  Bernie should pull his endorsement of Crooked ...
# 12    782553353242841088  "@trumplican2016: .@realDonaldTrump  There wil...
# 13    782544407593619457  I have created tens of thousands of jobs and w...
# 14    782541307168391168  I know our complex tax laws better than anyone...
# 15    782331741369462784  Heading to Pennsylvania for a big rally tonigh...
# 16    782330717539803136  Wow, just saw the really bad @CNN ratings. Peo...
# 17    782321125984436224  The so-called Commission on Presidential Debat...
# 18    782313153308884992  I won the debate if you decide without watchin...
# 19    782264189574377472  Crooked H is nasty to Sanders supporters behin...
# 20    782020266771812352  I believe in #AmericaFirst and that means FAMI...
# 21    781992481160323072  Thank you Novi, Michigan! Get out and VOTE #Tr...
# 22    781949464152006657  Thank you for your support - on my way now! Se...
# 23    781947646319665152  Join me in Pueblo, Colorado on Monday afternoo...
# 24    781926033159249920  For those few people knocking me for tweeting ...
# 25    781922648645185536  Why isn't Hillary 50 points ahead? Maybe it's ...
# 26    781861632167256064  The people are really smart in cancelling subs...
# 27    781838706030313472  Remember, don't believe "sources said" by the ...
# 28    781788223055994880  Did Crooked Hillary help disgusting (check out...
# 29    781785509639118848  Using Alicia M in the debate as a paragon of v...
# ...                  ...                                                ...
# 6417  727482940914057217  Hoosiers, head to the polls today. RT this if ...
# 6418  727318303065034753  When it comes to love and kindness, @AndraDayM...
# 6419  727280763381522432  We can't let all the progress we've made under...
# 6420  727226308330029061  When we stand together against the other side'...
# 6421  727211130192584705  RT @TheBriefing2016: In Indiana, Hillary Clint...
# 6443  Sun May 01 14:00:42 +0000 2016            5374           2212  Clinton
# 6444  Sun May 01 00:48:28 +0000 2016            6038           2113  Clinton
# 6445  Sat Apr 30 22:28:07 +0000 2016            3836           1621  Clinton
# 6446  Sat Apr 30 20:22:47 +0000 2016            1509            873  Clinton
#
# [6447 rows x 6 columns]

# %%
def percentInCaps(s):
    inCaps = sum(1 for c in s if c.isupper())
    inLowerCase = sum(1 for c in s if c.islower())
    return inCaps/float(inCaps + inLowerCase) 

def num_hashtags(s):
    return sum(1 for c in s if c == "#")

def num_mentions(s):
    return sum(1 for c in s if c == "@")

punctuation = '!"$%&\'()*+,-./:;<=>?[\\]^_`{|}~'
def percentPunctuation(s):
    return sum(1 for c in s if c in punctuation)/float(len(s))
    
tweets["percentPunctuation"] = tweets["text"].apply(lambda x: percentPunctuation(x)) 
tweets["percentInCaps"] = tweets["text"].apply(lambda x: percentInCaps(x))    
tweets["numHastags"] = tweets["text"].apply(lambda x: num_hashtags(x))
tweets["numMentions"] = tweets["text"].apply(lambda x: num_mentions(x))

#Get a summary of Clinton vs. Trump Tweet attributes
tweets.groupby("author").mean()
# Out:
#          favorite_count  retweet_count  percentPunctuation  percentInCaps  \
# author
# Clinton     5991.002167    3144.962229            0.063471       0.093032
# Trump      16600.378303    5974.324837            0.059060       0.139253
#
#          numHastags  numMentions
# author
# Clinton    0.129102     0.491022
# Trump      0.478707     0.661486

# %%
#Extract month,day,and hour from timestamp and append back to data frame
tweets["created_at"] = pd.to_datetime(tweets["created_at"])
tweets["hour"] = tweets["created_at"].apply(lambda x: x.hour)
tweets["day"] = tweets["created_at"].apply(lambda x: x.weekday())
tweets["month"] = tweets["created_at"].apply(lambda x: x.month)

#Take a look at the new frame
tweets.head()
# Out:
#                    id                                               text  \
# 0  783436108176629760  Thank you ARIZONA! This is a MOVEMENT like nob...
# 1  783393314309484544  My childcare plan makes a difference for worki...
# 2  783391423663964160  I will be watching the great Governor @Mike_Pe...
# 3  783390310969651200  Join me in Reno, Nevada tomorrow at 3:30pm! #A...
# 4  783149570721144832  Join me in Reno, Nevada on Wednesday at 3:30pm...
#
#            created_at  favorite_count  retweet_count author  \
# 0 2016-10-04 22:38:18            4229           1729  Trump
# 1 2016-10-04 19:48:15           11110           4719  Trump
# 2 2016-10-04 19:40:44           14211           4809  Trump
# 3 2016-10-04 19:36:19            5743           2053  Trump
# 4 2016-10-04 03:39:42           13895           6189  Trump
#
#    percentPunctuation  percentInCaps  numHastags  numMentions  hour  day  \
# 0            0.056338       0.330275           0            0    22    1
# 1            0.060606       0.068627           1            0    19    1
# 2            0.033333       0.075269           0            1    19    1
# 3            0.093750       0.217391           2            0    19    1
# 4            0.079365       0.217391           1            0     3    1
#
#    month
# 0     10
# 1     10
# 2     10
# 3     10
# 4     10
